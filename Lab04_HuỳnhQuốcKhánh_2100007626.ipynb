# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

# %%
path = '/content/drive/MyDrive/Dataset/Databai1_Lab04 - Databai1_Lab04.csv'

data = pd.read_csv(path)
data
# Out:
#     ID      Y    X1   X2     X3     X4       X5       X6    X7
# 0    1  36.98   5.1  400  51.37   4.24  1484.83  2227.25  2.06
# 1    2  13.74  26.4  400  72.33  30.87   289.94   434.90  1.33
# 2    3  10.08  23.8  400  71.44  33.01   320.79   481.19  0.97
# 3    4   8.53  46.4  400  79.15  44.61   164.76   247.14  0.62
# 4    5  36.42   7.0  450  80.47  33.84  1097.26  1645.89  0.22
# 5    6  26.59  12.6  450  89.90  41.26   605.06   907.59  0.76
# 6    7  19.07  18.9  450  91.48  41.88   405.37   608.05  1.71
# 7    8   5.96  30.2  450  98.60  70.79   253.70   380.55  3.93
# 8    9  15.52  53.8  450  98.05  66.82   142.27   213.40  1.97
# 9   10  56.61   5.6  400  55.69   8.92  1362.24  2043.36  5.08
# 10  11  26.72  15.1  400  66.29  17.98   507.65   761.48  0.60
# 11  12  20.80  20.3  400  58.94  17.79   377.60   566.40  0.90
# 12  13   6.99  48.4  400  74.74  33.94   158.05   237.08  0.63
# 13  14  45.93   5.8  425  63.71  11.95   130.66  1961.49  2.04
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(), annot = True, cmap='Blues')
plt.show()
# Out:
# <ipython-input-3-a21884817e78>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True, cmap='Blues')

# %% [markdown]
# LinearRegression đơn biến
# y(sản lượng) = mx(nhiệt độ )+b

# %%
#X1 thời gian
#Y sản lượng
plt.scatter(data['X1'],data['Y'])
plt.xlabel('Thời gian')
plt.ylabel('Sản lượng')
plt.show()

# %% [markdown]
# CODE CHAY

# %% [markdown]
# Lấy cột thời gian để train LinearRegression đơn biến
#
#
# Ta cũng có thể lấy các cột khác để train để tìm ra Y
#
#
# Công thức : Y= m*x+b
#
#
# Trong đó : y dữ liệu cần dự đoán
#
# m là độ dốc
#
# x là dữ liệu truyền vào
#
# b là bias

# %% [markdown]
# input là thời gian
#
#
# output là sản lượng
#
#
# Ta sẽ sử dụng Linear Regression để dự đoán sản lượng đạt được khi có thời gian là bao nhiêu

# %%
# Hàm dự đoán
# y là sản lượng
# x nhiệt độ
# def predict (x,m,bias):
#   return m*x+bias

# %%
# Hàm phương sai
# def cost_function(x,m,bias):
#   n=len(x)
#   sum_erro = 0
#   for i in range(n):
#     sum_erro +=(y[i]-(m*x[i]+bias))**2
#   return sum_erro/n

# %%
#cập nhập lại m
# def update_m(x,y,m,bias,dotre):
#   n=len(x)
#   #gán giá trị
#   m =0.0
#   b=0.0
#   for i in range(n):
#    m+=-2*x[i]*(y[i]-(x[i]*m+bias))
#    b+=-2*y[i]*(x[i]-(x[i]*m+bias))

#   m -=(m/n)*dotre
#   bias -=(b/n)*dotre

#   return m,bias

# %%
# def train(x,y,m,bias,dotre,solanlap):
#   cost_arr = []
#   for i in range(solanlap):
#     m,bias = update_m(x,y,m,bias,dotre)
#     cost=cost_function(x,m,bias)
#     cost_arr.append(cost)

#   return m,bias,cost_arr

# %%
# m,bias,cost = train(x,y,0.01,0.02,0.03,30)
# print('ket qua')
# print(m)
# print(bias)
# print(cost)

# %% [markdown]
# ================================================================================

# %% [markdown]
# SỬ DỤNG THƯ VIỆN

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error

# %% [markdown]
# Train
#
#
# Biểu diễn sai số :   R2_score, Mean_squared_error

# %% [markdown]
# LinearRegression đơn biến

# %%
# X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
#train
liner = LinearRegression()
liner.fit(data[['X1']],data['Y'])
#dự đoán
y_dudoan = liner.predict(data[['X1']])
#Đánh giá mô hình
r2 = r2_score(y_dudoan,data['Y'])
mean = mean_squared_error(y_dudoan,data['Y'])
print('y_dudoan',y_dudoan)
print('===================================================================')
print("======================Sai Số=======================================")
print('r2',r2)
print('mean',mean)
# Out:
# y_dudoan [37.71498333 19.29048071 21.53948103  1.99047824 36.0714831  31.22748241
#  25.77798163 16.00348024 -4.41052267 37.28248327 29.0649821  24.56698146
#   0.26047799 37.10948325 32.43848258 17.99298052 37.71498333 32.00598252
#  27.6809819  20.6744809  20.58798089  7.95897909 17.04148039 37.36898328
#  32.17898254 37.62848332 32.95748265]
# ...
# ======================Sai Số=======================================
# r2 -0.013090933439341867
# mean 146.69056787928378

# %% [markdown]
# ======================TEST========================================================

# %%
liner.predict([[10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([33.47648273])

# %%
#lấy m (Độ dốc)
m = liner.coef_
m
# Out:
# array([-0.86500012])

# %%
#lấy b (bias)
b= liner.intercept_
b
# Out:
# 42.12648396196511

# %% [markdown]
# y(sản lượng) = mx(nhiệt độ )+b

# %%
y_dudoan = m*10+b
y_dudoan
# Out:
# array([33.47648273])

# %% [markdown]
# Ta thấy hai kết quả đuề giống nhau

# %% [markdown]
# ================================================================================

# %% [markdown]
# X1 là nhiệt độ
# Y là sản lượng

# %%
plt.scatter(data['X1'],data['Y'])
plt.plot(data['X1'],m*data['X1']+b,color = 'r')

# %% [markdown]
# LinearRegression đa biến
#
# Công thức :Y = b+(m1*x1) +(m2+x2)+(mn+xn)

# %%
data.columns
# Out:
# Index(['ID', 'Y', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7'], dtype='object')

# %%
liner2 = LinearRegression()
liner2.fit(data[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7']], data['Y'] )

# %% [markdown]
# =========================================TEST=========================

# %%
#test
liner2.predict([[5.1 ,400 ,51.37 ,4.24 ,1484.83 ,227.25 ,2.06]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([12.99673351])

# %%
w=liner2.coef_ # lấy m
b=liner2.intercept_ #lấy b
print('Độ dốc',w)
print('Bias',b)
# Out:
# Độ dốc [-0.05036909  0.03590783  0.03830117 -0.17668363 -0.00253666  0.01698551
#   1.98009352]
# Bias -6.500354454483283

# %%
#test
y = -6.500354454483283 +(-0.05036909*5.1)+(0.03590783*400)+(0.03830117*51.37)+(-0.17668363*4.24)+(-0.00253666*1484.83)+(0.01698551*227.25)+(1.98009352*2.06)
y
# Out:
# 12.996728629116719

# %% [markdown]
# ==========================================================

# %%
y_dudoan=liner2.predict(data[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7']])

# %%
#saiso
r22 = r2_score(y_dudoan,data['Y'])
mean22 = mean_squared_error(y_dudoan,data['Y'])

print("Ket qua ", y_dudoan)
print('===================================================================')
# Out:
# Ket qua  [37.71498333 19.29048071 21.53948103  1.99047824 36.0714831  31.22748241
#  25.77798163 16.00348024 -4.41052267 37.28248327 29.0649821  24.56698146
#   0.26047799 37.10948325 32.43848258 17.99298052 37.71498333 32.00598252
#  27.6809819  20.6744809  20.58798089  7.95897909 17.04148039 37.36898328
#  32.17898254 37.62848332 32.95748265]
# ...

# %%
solanlap = [i for i in range(27)]
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(10,5))
ax1.scatter(data['X1'],y_dudoan,color='r')
ax1.set(xlabel='Nhiệt độ', ylabel='Sản lượng')
ax1.set(title='Biểu đồ kết quả đã train')
ax1.grid()

ax2.scatter(data['X1'],data['Y'],color='b')
ax2.set(xlabel='Nhiệt độ', ylabel='Sản lượng')
ax2.set(title='Biểu đồ kết quả chưa train')
ax2.grid()

# %%
print("======================Sai Số=======================================")
print('r22',r22)
print('mean22',mean22)
# Out:
# ======================Sai Số=======================================
# r22 -0.013090933439341867
# mean22 146.69056787928378

# %% [markdown]
# Bài 2:

# %%
path2 = '/content/drive/MyDrive/Dataset/Databai2_Lab04.csv'
data2 = pd.read_csv(path2)
data2
# Out:
#     Tuổi  HATT
# 0     39   144
# 1     36   136
# 2     45   138
# 3     47   145
# 4     65   162
# 5     46   142
# 6     67   170
# 7     42   124
# 8     67   158
# 9     56   154
# 10    64   162
# 11    56   150
# 12    59   140
# 13    34   110
# 14    42   128
# 15    48   130
# 16    45   135
# 17    17   114
# 18    20   116
# 19    19   124

# %% [markdown]
# ![Screenshot 2023-11-04 185425.png](data:image/png;base64,...)

# %%
solalap = [i for i in range(20)]
plt.scatter(solalap,data2['Tuổi'],color='r' ,label='Tuổi')
plt.scatter(solalap,data2['HATT'],color='b' ,label='HATT')
plt.legend()

# %% [markdown]
# ======================================================

# %% [markdown]
# =====Train LinearRegression======

# %%
x=data2['HATT']
y=data2[['Tuổi']] # là mảng 2 chiều
liner3 = LinearRegression()
liner3.fit(y,x)
y_dudoan3 = liner3.predict(y)

# %%
#teest mô hình
liner3.predict([[45]])
m2 = liner3.coef_
b2 = liner3.intercept_
print('Độ dốc',m2)
print('Bias',b2)

y = m2 *45 + b2
print(y)
# Out:
# Độ dốc [0.96241301]
# Bias 95.11772527813483
# [138.42631089]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
theta = liner3.coef_[0]
print(theta)
# Out:
# 0.962413013607553

# %%
# def load_data (data):
#   y =data2['HATT']
#   y=np.array([y]).T
#   x=data2['Tuổi']
#   x= np.array(x)


#   return x,y

# %%
x,y = load_data(data2)

# %%
#hàm mát mát
# def loss (x,y,theta):

#   m=len(x)
#   h= x @ theta
#   loss = 1/(2*m)*np.sum((y-h)**2)
#   return loss

# %%
# def dl(X,y,theta):
#   theta = theta.reshape(-1,1)
#   m=len(X)
#   return -(1/m)*np.sum(X*(y-X @ theta),axis=0)

# %%
# def gradient_descemt():
#    m,n = X.shape

#    theta = np.random.randn(n)
#    iter = 100001
#    apha = 0.003

#    for i in range(iter):

#       theta = theta - apha *dl(X,y,theta)


#       loss = loss(X,y,theta)

#       if i%20000 ==0:
#         print('Iter',i,'loss',loss)

#    return theta

# %%
y=m2*data2['Tuổi']+b2
plt.scatter(data2['Tuổi'],data2['HATT'])
plt.plot(data2['Tuổi'],y,color ='r')
plt.xlabel('Tuổi')
plt.ylabel('Huyết áp')
plt.grid()
plt.show()

# %%
#sai số
print('r222',r2_score(y_dudoan3,data2['HATT']))
print('mean222',mean_squared_error(y_dudoan3,data2['HATT']))
# Out:
# r222 0.6912396414763102
# mean222 64.52126235539205
